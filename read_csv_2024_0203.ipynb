# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/teach-visulization/blob/main/read_csv_2024_0203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv('https://www.hpa.gov.tw/File/Attach/12712/File_14622.csv')

df.head()
# Out:
#    依年度別分by year  有效樣本數Sample Size  男Male (%)  女Female (%)  不分性別Both (%)
# 0          2008             15860      46.18        28.37         37.48
# 1          2009             15418      47.73        27.87         37.98
# 2          2010             15499      48.53        28.04         38.53
# 3          2011             16119      48.86        28.56         38.95
# 4          2012             16013      49.06        29.35         39.30

# %%
df1=pd.read_csv('ccc.csv')

df1.head()
# Out:
#    依年度別分by year  有效樣本數Sample Size  男Male (%)  女Female (%)  不分性別Both (%)
# 0          2008             15860      46.18        28.37         37.48
# 1          2009             15418      47.73        27.87         37.98
# 2          2010             15499      48.53        28.04         38.53
# 3          2011             16119      48.86        28.56         38.95
# 4          2012             16013      49.06        29.35         39.30
