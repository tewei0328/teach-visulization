# %% [markdown]
# <a href="https://colab.research.google.com/github/tewei0328/visulization/blob/main/viz1_yfinance_plot_TWII_TSLA_BTC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Yahoo Finance
# https://finance.yahoo.com/world-indices

# %%
# !pip install yfinance

# %%
import yfinance
stock1=yfinance.Ticker('^TWII')
df1=stock1.history(period='1y')
df1.head()
# Out:
#                     Open          High           Low         Close   Volume  \
# Date
# 2021-03-18  16264.610352  16410.019531  16264.610352  16287.839844  5694800
# 2021-03-19  16186.459961  16186.459961  16022.169922  16070.240234  6753400
# 2021-03-22  16065.500000  16235.629883  15983.769531  16189.219727  7093200
# 2021-03-23  16250.200195  16351.379883  16166.290039  16177.589844  7291400
# 2021-03-24  15994.959961  16125.540039  15967.950195  16032.120117  5549900
#
#             Dividends  Stock Splits
# Date
# 2021-03-18          0             0
# 2021-03-19          0             0
# 2021-03-22          0             0
# 2021-03-23          0             0
# 2021-03-24          0             0

# %%
df1.Close.plot(figsize=(15,3))

# %%
stock2=yfinance.Ticker('TSLA')
df2=stock2.history(period='1y')
df2.Close.plot(figsize=(15,3))

# %%
stock3=yfinance.Ticker('BTC-USD')
df3=stock3.history(period='1y')
df3.Close.plot(figsize=(15,3))

# %%
import pandas as pd
df_many = pd.concat([df1.Close, df2.Close,df3.Close], axis=1)
df_many.columns=['TWII','TSLA','BTC']
df_many.head()
# Out:
#                     TWII        TSLA           BTC
# Date
# 2021-03-18  16287.839844  653.159973  57858.921875
# 2021-03-19  16070.240234  654.869995  58346.652344
# 2021-03-20           NaN         NaN  58313.644531
# 2021-03-21           NaN         NaN  57523.421875
# 2021-03-22  16189.219727  670.000000  54529.144531

# %%
df_many.plot(figsize=(15,5))

# %%
df_many['TWII']=df_many['TWII']/df_many.iloc[0][0]
df_many['TSLA']=df_many['TSLA']/df_many.iloc[0][1]
df_many['BTC']=df_many['BTC']/df_many.iloc[0][2]
df_many.head()
# Out:
#                 TWII      TSLA       BTC
# Date
# 2021-03-18  1.000000  1.000000  1.000000
# 2021-03-19  0.986640  1.002618  1.008430
# 2021-03-20       NaN       NaN  1.007859
# 2021-03-21       NaN       NaN  0.994201
# 2021-03-22  0.993945  1.025782  0.942450

# %%
df_many.plot(figsize=(15,5))
