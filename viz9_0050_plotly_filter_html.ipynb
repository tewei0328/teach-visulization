# %%
import plotly
import pandas as pd

# Load data
df = pd.read_csv("https://raw.githubusercontent.com/tewei0328/teach-visulization/main/0050.csv")

# %%
df.head()
# Out:
#          date    Volume   Open   High    Low  Close
# 0  2003-06-30   9930000  37.10  37.40  36.92  37.08
# 1  2003-07-01  14290000  37.09  38.10  37.09  38.05
# 2  2003-07-02  16232000  38.17  38.82  38.10  38.69
# 3  2003-07-03  16839000  40.60  40.60  38.81  39.00
# 4  2003-07-04  12491000  39.10  39.26  38.75  39.26

# %%
import plotly.graph_objects as go
line1 = go.Scatter(x=df['date'], y=df['Close'], name='Close')
fig  = go.Figure(line1)
fig.show()
plotly.offline.plot(fig, filename='0050.html')

#x=plotly.offline.plot(fig, include_plotlyjs=False, output_type='div')
#text_file = open("sample.txt", "w")
#n = text_file.write(x)
#text_file.close()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.shape
# Out:
# (4968, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4968 entries, 0 to 4967
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4968 non-null   object
#  1   Volume  4968 non-null   int64
#  2   Open    4968 non-null   float64
#  3   High    4968 non-null   float64
#  4   Low     4968 non-null   float64
#  5   Close   4968 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 233.0+ KB

# %%
df.describe()
# Out:
#              Volume         Open         High          Low        Close
# count  4.968000e+03  4968.000000  4968.000000  4968.000000  4968.000000
# mean   1.024800e+07    70.331502    70.691870    69.918553    70.330304
# std    8.298715e+06    26.707373    26.799427    26.579494    26.698934
# min    5.580000e+05    29.100000    30.110000    28.530000    29.500000
# 25%    4.702816e+06    52.600000    52.987500    52.200000    52.550000
# 50%    7.951796e+06    60.750000    61.100000    60.300000    60.750000
# 75%    1.321804e+07    81.212500    81.512500    80.850000    81.200000
# max    1.376805e+08   152.200000   152.400000   151.100000   152.000000

# %%
df1.head()
# Out:
#           Date        Open        High         Low       Close    Volume  \
# 474 2017-01-03  115.800003  116.330002  114.760002  116.150002  28781900
# 475 2017-01-04  115.849998  116.510002  115.750000  116.019997  21118100
# 476 2017-01-05  115.919998  116.860001  115.809998  116.610001  22193600
# 477 2017-01-06  116.779999  118.160004  116.470001  117.910004  31751900
# 478 2017-01-09  117.949997  119.430000  117.940002  118.989998  33387600
#
#        Adjusted          dn        mavg          up   direction
# 474  115.648597  109.824879  114.832833  119.840788  Increasing
# 475  115.519154  110.890541  115.181000  119.471459  Increasing
# 476  116.106611  111.966073  115.510667  119.055261  Increasing
# 477  117.401002  113.076409  115.863333  118.650257  Increasing
# 478  118.476334  113.863686  116.216833  118.569981  Increasing

# %%
type(df.Date)
# Out:
# pandas.core.series.Series

# %%
df['date'] = pd.to_datetime(df['date'])
df['date'] > pd.to_datetime('2020-01-01')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4963     True
# 4964     True
# 4965     True
# 4966     True
# 4967     True
# Name: date, Length: 4968, dtype: bool

# %%
df1=df[df['date'] > pd.to_datetime('2020-01-01')]

# %%
line1 = go.Scatter(x=df1['date'], y=df1['Close'], name='Close')
fig  = go.Figure(line1)
fig.show()
plotly.offline.plot(fig, filename='0050a.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
